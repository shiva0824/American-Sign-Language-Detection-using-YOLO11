# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 898.5/898.5 kB 43.9 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO

# %% [markdown]
# #Loading Trained model

# %%
model = YOLO('best.pt')

# %% [markdown]
# #Prediction on alphabets

# %%
folder_path = "/content/new_dataset"
image_files = ['A.jpg', 'H.jpg', 'K.jpg', 'L.jpg', 'N.jpg', 'Q.jpg', 'Y.jpg']

for image in image_files:
    image_path = os.path.join(folder_path, image)
    result = model.predict(source=image_path, save=True)
# Out:
# image 1/1 /content/new_dataset/A.jpg: 640x448 1 A, 28.6ms
# Speed: 2.9ms preprocess, 28.6ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 448)
# Results saved to runs/detect/predict
#
# image 1/1 /content/new_dataset/H.jpg: 448x640 1 H, 29.2ms
# Speed: 2.8ms preprocess, 29.2ms inference, 1.2ms postprocess per image at shape (1, 3, 448, 640)
# Results saved to runs/detect/predict
#
# image 1/1 /content/new_dataset/K.jpg: 640x448 1 K, 28.2ms
# Speed: 2.4ms preprocess, 28.2ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 448)
# Results saved to runs/detect/predict
#
# image 1/1 /content/new_dataset/L.jpg: 640x640 1 L, 38.3ms
# Speed: 2.9ms preprocess, 38.3ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict
#
# image 1/1 /content/new_dataset/N.jpg: 640x544 1 N, 36.8ms
# Speed: 3.2ms preprocess, 36.8ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 544)
# Results saved to runs/detect/predict
#
# ...

# %% [markdown]
# #Prediction on words

# %%
folder_path = "/content/new_dataset"
image_files = ['hello.jpg', 'cup.jpg', 'thank_you.jpg']

for image in image_files:
    image_path = os.path.join(folder_path, image)
    result = model.predict(source=image_path, save=True)
# Out:
# image 1/1 /content/new_dataset/hello.jpg: 448x640 1 hello, 29.4ms
# Speed: 4.6ms preprocess, 29.4ms inference, 1.3ms postprocess per image at shape (1, 3, 448, 640)
# Results saved to runs/detect/predict
#
# image 1/1 /content/new_dataset/cup.jpg: 384x640 1 cup, 24.9ms
# Speed: 2.2ms preprocess, 24.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/predict
#
# image 1/1 /content/new_dataset/thank_you.jpg: 448x640 1 thank-you, 29.2ms
# Speed: 1.7ms preprocess, 29.2ms inference, 1.1ms postprocess per image at shape (1, 3, 448, 640)
# Results saved to runs/detect/predict

# %% [markdown]
# #Prediction results

# %%
import glob
import os
from IPython.display import Image as IPyImage, display

folder_path = max(glob.glob('/content/runs/detect/predict*/'), key=os.path.getmtime)
for img in glob.glob(f'{folder_path}/*.jpg')[:]:
    display(IPyImage(filename=img, width=500))
    print("\n")
